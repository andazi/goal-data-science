# %%
from urllib.request import urlopen

# %%
url = "https://mydramalist.com/749183-fantasy-sonata"

# %%
page = urlopen(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 page = urlopen(url)
#
# File ~/anaconda3/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/anaconda3/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File ~/anaconda3/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File ~/anaconda3/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File ~/anaconda3/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/anaconda3/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
from urllib.request import Request, urlopen

url = 'https://mydramalist.com/749183-fantasy-sonata'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

req = Request(url, headers=headers)

try:
    page = urlopen(req)
    print(page)
    # Continue with your code...
except Exception as e:
    print(f"Error: {e}")
# Out:
# <http.client.HTTPResponse object at 0x7f7d6d905810>

# %%
html_bytes = page.read()
print(html_bytes)
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US">\n<head>\n<title>Love Song for Illusion (2024) - MyDramaList</title>\n<link rel="dns-prefetch" href="//fonts.gstatic.com">\n<link rel="dns-prefetch" href="//fonts.googleapis.com">\n<link rel="dns-prefetch" href="//apis.google.com">\n<link rel="dns-prefetch" href="//tpc.googlesyndication.com">\n<link rel="dns-prefetch" href="//googleads.g.doubleclick.net">\n<link rel="dns-prefetch" href="//securepubads.g.doubleclick.net">\n<link rel="preconnect" href="//fonts.gstatic.com" crossorigin>\n<link rel="preconnect" href="//fonts.googleapis.com" crossorigin>\n<link rel="preconnect" href="//apis.google.com" crossorigin>\n<link rel="preconnect" href="//tpc.googlesyndication.com" crossorigin>\n<link rel="preconnect" href="//googleads.g.doubleclick.net" crossorigin>\n<link rel="preconnect" href="//securepubads.g.doubleclick.net" crossorigin>\n<link rel="canonical" href="https://mydramalist.com/749183-fantasy-sonata"/>\n<meta name="description" content="Love Song for Illusion (Korean Drama); \xed\x99\x98\xec\x83\x81\xec\x97\xb0\xea\xb0\x80; Fantasy Love Song;Fantasy Love Story;Fantasy Sonata;Fantastic Love Story;Hwansangyeonga; It tells both the"/>\n<link href="https://i.mydramalist.com/vXWWbe_4f.jpg" rel="image_src">\n<meta property="og:title" content="Love Song for Illusion" />\n<meta property="og:image" content="https://i.mydramalist.com/vXWWbe_4f.jpg"/>\n<meta property="og:url" content="https://mydramalist.com/749183-fantasy-sonata" />\n<meta property="og:type" content="video.tv_show" />\n<meta property="fb:app_id" content="118726721587830" />\n<meta property="og:description" content="It tells both the heart-fluttering love story and fierce obsession of a King with two opposite personalities and an assassin girl who wants to kill him..." />\n<meta property="mdl:rid" content="749183" />\n<meta property="mdl:type" content="titles" />\n<link href="/dist/css/show.css?v=6.6.57" rel="stylesheet" type="text/css" />\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>\n<meta name="csrf-token" content="ah4Ms39gXDkmvj6o" />\n<meta name=\'webgains-site-verification\' content=\'1yuelvqb\' />\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta name="theme-color" content="#015284" />\n<meta name="dailymotion-domain-verification" content="dmg5lpc1ng53ymvet" />\n<script type="text/javascript" src="/assets/js/jquery.min.js"></script>\n<link rel="preload" as="style" href="/dist/css/main.css?v=6.6.57d79" />\n<link rel="preload" as="style" href="/css/overwrite.css?v=6.6.57d79" media="none" onload="if(media!==\'all\')media=\'all\'" />\n<link rel="preload" as="script" href="/dist/js/main.js?v=6.6.57d79" />\n<link rel="stylesheet" href="/dist/css/main.css?v=6.6.57d79" />\n<link rel="stylesheet" href="/css/overwrite.css?v=6.6.57d79" media="none" onload="if(media!==\'all\')media=\'all\'" />\n<link rel="preload" as="style" href="/css/fontawesome/css/all.min.css?v=6.6.57a" rel="stylesheet">\n<link rel="stylesheet" href="//fonts.googleapis.com/css?family=Lato:300,350,300i,400,400i,500,600,700&display=swap">\n<script rel="stylesheet" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>\n<script type="text/javascript" src="/js/adsbygoogle.js?v=6.6.57g3"></script>\n<link href="/css/fontawesome/css/all.min.css?v=6.6.57a" rel="stylesheet">\n<link defer rel="stylesheet" as="script" href="/js/tether.min.js" />\n<link defer rel="stylesheet" as="script" href="/js/bootstrap.min.js" />\n<link defer rel="stylesheet" as="script" href="/js/jquery.qtip.min.js?v=6.6.57" />\n<script type="text/javascript" src="/js/tether.min.js"></script>\n<script type="text/javascript" src="/js/bootstrap.min.js"></script>\n<script type="text/javascript" src="/js/jquery.qtip.min.js?v=6.6.57"></script>\n<script>\nwindow.mdlhb = window.mdlhb || {};\nwindow.mdlhb.kvs = window.mdlhb.kvs || {};\nvar isMobile = false;\nvar isMobilePh = false;\n ...

# %%
html = html_bytes.decode("utf-8")
html
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n<head>\n<title>Love Song for Illusion (2024) - MyDramaList</title>\n<link rel="dns-prefetch" href="//fonts.gstatic.com">\n<link rel="dns-prefetch" href="//fonts.googleapis.com">\n<link rel="dns-prefetch" href="//apis.google.com">\n<link rel="dns-prefetch" href="//tpc.googlesyndication.com">\n<link rel="dns-prefetch" href="//googleads.g.doubleclick.net">\n<link rel="dns-prefetch" href="//securepubads.g.doubleclick.net">\n<link rel="preconnect" href="//fonts.gstatic.com" crossorigin>\n<link rel="preconnect" href="//fonts.googleapis.com" crossorigin>\n<link rel="preconnect" href="//apis.google.com" crossorigin>\n<link rel="preconnect" href="//tpc.googlesyndication.com" crossorigin>\n<link rel="preconnect" href="//googleads.g.doubleclick.net" crossorigin>\n<link rel="preconnect" href="//securepubads.g.doubleclick.net" crossorigin>\n<link rel="canonical" href="https://mydramalist.com/749183-fantasy-sonata"/>\n<meta name="description" content="Love Song for Illusion (Korean Drama); 환상연가; Fantasy Love Song;Fantasy Love Story;Fantasy Sonata;Fantastic Love Story;Hwansangyeonga; It tells both the"/>\n<link href="https://i.mydramalist.com/vXWWbe_4f.jpg" rel="image_src">\n<meta property="og:title" content="Love Song for Illusion" />\n<meta property="og:image" content="https://i.mydramalist.com/vXWWbe_4f.jpg"/>\n<meta property="og:url" content="https://mydramalist.com/749183-fantasy-sonata" />\n<meta property="og:type" content="video.tv_show" />\n<meta property="fb:app_id" content="118726721587830" />\n<meta property="og:description" content="It tells both the heart-fluttering love story and fierce obsession of a King with two opposite personalities and an assassin girl who wants to kill him..." />\n<meta property="mdl:rid" content="749183" />\n<meta property="mdl:type" content="titles" />\n<link href="/dist/css/show.css?v=6.6.57" rel="stylesheet" type="text/css" />\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>\n<meta name="csrf-token" content="ah4Ms39gXDkmvj6o" />\n<meta name=\'webgains-site-verification\' content=\'1yuelvqb\' />\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta name="theme-color" content="#015284" />\n<meta name="dailymotion-domain-verification" content="dmg5lpc1ng53ymvet" />\n<script type="text/javascript" src="/assets/js/jquery.min.js"></script>\n<link rel="preload" as="style" href="/dist/css/main.css?v=6.6.57d79" />\n<link rel="preload" as="style" href="/css/overwrite.css?v=6.6.57d79" media="none" onload="if(media!==\'all\')media=\'all\'" />\n<link rel="preload" as="script" href="/dist/js/main.js?v=6.6.57d79" />\n<link rel="stylesheet" href="/dist/css/main.css?v=6.6.57d79" />\n<link rel="stylesheet" href="/css/overwrite.css?v=6.6.57d79" media="none" onload="if(media!==\'all\')media=\'all\'" />\n<link rel="preload" as="style" href="/css/fontawesome/css/all.min.css?v=6.6.57a" rel="stylesheet">\n<link rel="stylesheet" href="//fonts.googleapis.com/css?family=Lato:300,350,300i,400,400i,500,600,700&display=swap">\n<script rel="stylesheet" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>\n<script type="text/javascript" src="/js/adsbygoogle.js?v=6.6.57g3"></script>\n<link href="/css/fontawesome/css/all.min.css?v=6.6.57a" rel="stylesheet">\n<link defer rel="stylesheet" as="script" href="/js/tether.min.js" />\n<link defer rel="stylesheet" as="script" href="/js/bootstrap.min.js" />\n<link defer rel="stylesheet" as="script" href="/js/jquery.qtip.min.js?v=6.6.57" />\n<script type="text/javascript" src="/js/tether.min.js"></script>\n<script type="text/javascript" src="/js/bootstrap.min.js"></script>\n<script type="text/javascript" src="/js/jquery.qtip.min.js?v=6.6.57"></script>\n<script>\nwindow.mdlhb = window.mdlhb || {};\nwindow.mdlhb.kvs = window.mdlhb.kvs || {};\nvar isMobile = false;\nvar isMobilePh = false;\nvar isGodzilla = false;\nvar themeMode = 0;\n ...

# %%
# extract title
title_index = html.find("<title>")
print(title_index)
# Out:
# 43

# %%
start_index = title_index + len("<title>")
print(start_index)
# Out:
# 50
